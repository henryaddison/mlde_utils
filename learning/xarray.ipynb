# %%
import numpy as np

import pandas as pd

import xarray as xr

# %%
data = xr.DataArray(np.random.randn(2, 3), dims=("x", "y"), coords={"x": [10, 20], "y": [1, 2, 3]})

data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[ 0.68179778, -0.61354086, -1.50194949],
#        [ 0.47249427, -1.02564452, -1.41062109]])
# Coordinates:
#   * x        (x) int64 10 20
#   * y        (y) int64 1 2 3

# %%
data.y
# Out:
# <xarray.DataArray 'y' (y: 3)>
# array(['a', 'b', 'c'], dtype='<U1')
# Coordinates:
#   * y        (y) <U1 'a' 'b' 'c'

# %%
data.values
# Out:
# array([[-0.31556095,  0.76158432,  0.37406739],
#        [ 0.57189429, -1.31359869, -0.72245367]])

# %%
data.dims
# Out:
# ('x', 'y')

# %%
data.coords
# Out:
# Coordinates:
#   * x        (x) int64 10 20
#   * y        (y) <U1 'a' 'b' 'c'

# %%
data.attrs
# Out:
# {}

# %%
data[0,:].values
# Out:
# array([-0.31556095,  0.76158432,  0.37406739])

# %%
data.loc[:, 'c'].values
# Out:
# array([ 0.37406739, -0.72245367])

# %%
data.isel(y=0).values
# Out:
# array([-0.31556095,  0.57189429])

# %%
data.sel(x=10, y='c').values
# Out:
# array(0.37406739)

# %%
data.mean(dim="x")
# Out:
# <xarray.DataArray (y: 3)>
# array([ 0.12816667, -0.27600718, -0.17419314])
# Coordinates:
#   * y        (y) <U1 'a' 'b' 'c'

# %%
a = xr.DataArray(np.random.randn(3), [data.coords["y"]])

# %%
 b = xr.DataArray(np.random.randn(4), dims="z")

# %%
a
# Out:
# <xarray.DataArray (y: 3)>
# array([-0.84557489,  0.9991051 ,  3.14977704])
# Coordinates:
#   * y        (y) <U1 'a' 'b' 'c'

# %%
b
# Out:
# <xarray.DataArray (z: 4)>
# array([ 1.28298034, -1.07524803,  1.90984282,  0.66287119])
# Dimensions without coordinates: z

# %%
a.values
# Out:
# array([-0.84557489,  0.9991051 ,  3.14977704])

# %%
b.values
# Out:
# array([ 1.28298034, -1.07524803,  1.90984282,  0.66287119])

# %%
data.plot()
